# %%
# !pip install langchain 
# !pip install openai
# !pip install python-dotenv
# !pip install langchain-openai

# %%
# Import required libraries
import os  
from dotenv import load_dotenv

# %%
# Import LangChain modules
# from langchain.llms import OpenAI
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

# %%
# Load OpenAI API key from .env file
load_dotenv()
os.environ["OPENAI_API_KEY"]=''

# %%
# Create Chat model using OpenAI 
chat_model = ChatOpenAI()

# %%
# Define a prompt text  
text = "What would be a good name for a new national park with a jungle terrain?"

# %%
# Create a HumanMessage schema object containing the prompt 
messages = [HumanMessage(content=text)]

# %%
# Pass Messags to chat model for inference
chat_model.invoke(messages)
# Out:
# AIMessage(content='Emerald Canopy National Park', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 23, 'total_tokens': 29, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CcG2qW8kKmmAivrMIdnL8cn4XaqxI', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--3c392ab5-db68-46b3-9469-094aee1fbf1b-0', usage_metadata={'input_tokens': 23, 'output_tokens': 6, 'total_tokens': 29, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# Initial prompt and response
prompt = "What would be a good name for a new national park with a jungle terrain?"
response = chat_model.invoke(prompt) 
print(response)

# Continue conversation to get more options
followup = "Could you provide 3 more potential names?"
response2 = chat_model.invoke(followup)  
print(response2)

followup2 = "Could you provide 3 more potential names, which has something related to jungle in name?"
response3 = chat_model.invoke(followup2)
print(response3)
# Out:
# content='Emerald Canopy National Park' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 23, 'total_tokens': 29, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CcG31DrjxBuGudB6amJYKieScxAFp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--6c7824b2-088a-442f-8d63-73c5d8290736-0' usage_metadata={'input_tokens': 23, 'output_tokens': 6, 'total_tokens': 29, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content="1. Luna's Whiskers\n2. Purrfect Haven\n3. Feline Retreat" additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 16, 'total_tokens': 36, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CcG31EH9mdwckokI4qiGpxbEERmT7', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--57150852-7862-48a1-ad42-486b9ed1757c-0' usage_metadata={'input_tokens': 16, 'output_tokens': 20, 'total_tokens': 36, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content='1. Jungle Explorer Adventures\n2. Wild Jungle Expedition Tours\n3. Tropical Jungle Safari Co.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 25, 'total_tokens': 45, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CcG33uBOBtDEFQxieSgDQCWFsLV2r', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--e325edc5-0d4c-4068-bca6-e6eea8c8be34-0' usage_metadata={'input_tokens': 25, 'output_tokens': 20, 'total_tokens': 45, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# Prompt with all details 
prompt = "What would be a good name for a new national park with a jungle terrain? Give new name"

# Get initial suggestion
response = chat_model.invoke(prompt) 
print(response.content)

# Ask for alternatives fitting details
followup = "Could you suggest 5 more names for this jungle park with wild animals?"

# Get and format additional names 
alternatives = chat_model.invoke(followup).content
print("\nOther Options:")
for name in alternatives.split("\n"):
  print(f"- {name}")

# Ask for creative name ideas
followup2 = "Could you provide 3 more potential names, which has something related to lake in name?"

# Get and format creative names
creative = chat_model.invoke(followup2).content
print("\nCreative Ideas:") 
for name in creative.split("\n"):
  print(f"- {name}")
# Out:
# Emerald Canopy National Park
#
# Other Options:
# - 1. Wild Safari Land
# - 2. Jungle Kingdom
# - 3. Beastly Paradise
# - 4. Safari World
# - 5. Animal Kingdom Adventure Park
#
# Creative Ideas:
# - 1. Lakeview Haven
# - 2. Crystal Lake Retreat
# - 3. Serene Lakeside Escape
